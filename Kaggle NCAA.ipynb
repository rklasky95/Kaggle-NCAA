# %%
import pandas as pd

df = pd.read_csv('/Users/jeffreyebert/Downloads/mens-machine-learning-competition-2019/MasseyOrdinals.zip')

# %%
df
# Out:
#          Season  RankingDayNum SystemName  TeamID  OrdinalRank
# 0          2003             35        SEL    1102          159
# 1          2003             35        SEL    1103          229
# 2          2003             35        SEL    1104           12
# 3          2003             35        SEL    1105          314
# 4          2003             35        SEL    1106          260
# 5          2003             35        SEL    1107          249
# 6          2003             35        SEL    1108          228
# 7          2003             35        SEL    1110          204
# 8          2003             35        SEL    1111          183
# 9          2003             35        SEL    1112           26
# 10         2003             35        SEL    1113           89
# 11         2003             35        SEL    1114          110
# 12         2003             35        SEL    1115          287
# 13         2003             35        SEL    1116          143
# ...

# %%
zip_file = ZipFile('/Users/jeffreyebert/Downloads/mens-machine-learning-competition-2019/PlayByPlay_2010.zip')
dfs = {text_file.filename: pd.read_csv(zip_file.open(text_file.filename))
       for text_file in zip_file.infolist()
       if text_file.filename.endswith('.csv')}

# %%
dfs
# Out:
# {'Events_2010.csv':          EventID  Season  DayNum  WTeamID  LTeamID  WPoints  LPoints  \
#  0              1    2010       7     1143     1293        0        0
#  1              2    2010       7     1143     1293        0        0
#  2              3    2010       7     1143     1293        0        0
#  3              4    2010       7     1143     1293        0        0
#  4              5    2010       7     1143     1293        0        0
#  5              6    2010       7     1143     1293        2        0
#  6              7    2010       7     1143     1293        0        0
#  7              8    2010       7     1143     1293        0        0
#  8              9    2010       7     1143     1293        2        2
#  9             10    2010       7     1143     1293        0        0
#  10            11    2010       7     1143     1293        4        2
#  11            12    2010       7     1143     1293        0        0
# ...
